# %% [markdown]
# # SUYASH PRATAP SINGH

# %%
#Importing Required library
import pandas as pd
import numpy  as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load the dataset
kp = pd.read_csv(r'C:\Users\Admin\Downloads\2. Cars Data1.csv')

# %%
#print first five columns
kp.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
#print last five columns
kp.tail()
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 427  $38,203          2.4        5.0       197.0      21.0         28.0
# 428  $40,083          2.3        5.0       242.0      20.0         26.0
# 429  $42,573          2.9        6.0       268.0      19.0         26.0
# 430  $24,641          1.9        4.0       170.0      22.0         29.0
# 431  $33,112          2.5        5.0       208.0      20.0         27.0
#
#      Weight  Wheelbase  Length
# 427  3450.0      105.0   186.0
# 428  3450.0      105.0   186.0
# ...

# %%
#print random five column
kp.sample(5)
# Out:
#            Make            Model   Type  Origin DriveTrain      MSRP  \
# 218         Kia        Rio Cinco  Wagon    Asia      Front  $11,905
# 175     Hyundai  Elantra GLS 4dr  Sedan    Asia      Front  $13,839
# 282     Mercury     Sable GS 4dr  Sedan     USA      Front  $21,595
# 55        Buick  Park Avenue 4dr  Sedan     USA      Front  $35,545
# 419  Volkswagen        Passat W8  Wagon  Europe      Front  $40,235
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 218  $11,410          1.6        4.0       104.0      26.0         33.0
# 175  $12,781          2.0        4.0       138.0      26.0         34.0
# 282  $19,848          3.0        6.0       155.0      20.0         27.0
# 55   $32,244          3.8        6.0       205.0      20.0         29.0
# 419  $36,956          4.0        8.0       270.0      18.0         25.0
#
#      Weight  Wheelbase  Length
# 218  2447.0       95.0   167.0
# 175  2635.0      103.0   178.0
# ...

# %%
#print shape of dataset
kp.shape
# Out:
# (432, 15)

# %%
#print column of dataset
kp.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
#print datatype of each column
kp.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
#print index of dataset
kp.index
# Out:
# RangeIndex(start=0, stop=432, step=1)

# %%
kp.nunique()
# Out:
# Make            38
# Model          425
# Type             6
# Origin           3
# DriveTrain       3
# MSRP           410
# Invoice        425
# EngineSize      43
# Cylinders        7
# Horsepower     110
# MPG_City        28
# MPG_Highway     33
# Weight         348
# Wheelbase       40
# Length          67
# dtype: int64

# %%
kp.count()
# Out:
# Make           428
# Model          428
# Type           428
# Origin         428
# DriveTrain     428
# MSRP           428
# Invoice        428
# EngineSize     428
# Cylinders      426
# Horsepower     428
# MPG_City       428
# MPG_Highway    428
# Weight         428
# Wheelbase      428
# Length         428
# dtype: int64

# %%
kp['Cylinders'].unique()
# Out:
# array([ 6.,  4.,  8., nan, 10.,  3., 12.,  5.])

# %%
#full information of dataset
kp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 50.8+ KB

# %%
#statistical information of dataset
kp.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  428.000000  426.000000  428.000000  428.000000   428.000000
# mean     3.196729    5.807512  215.885514   20.060748    26.843458
# std      1.108595    1.558443   71.836032    5.238218     5.741201
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.375000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.250000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  428.000000  428.000000
# mean   3577.953271  108.154206  186.362150
# std     758.983215    8.311813   14.357991
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# ...

# %%
kp['Wheelbase'].value_counts()
# Out:
# 107.0    45
# 103.0    30
# 106.0    27
# 112.0    25
# 104.0    24
# 105.0    21
# 115.0    20
# 109.0    17
# 111.0    17
# 102.0    16
# 101.0    16
# 110.0    15
# 108.0    14
# 113.0    13
# 119.0    12
# 95.0     11
# 98.0     11
# 99.0     11
# 114.0    10
# 93.0      9
# 118.0     8
# 116.0     7
# 100.0     7
# 96.0      5
# 121.0     5
# 130.0     4
# 123.0     4
# 97.0      3
# 124.0     3
# 89.0      2
# 144.0     2
# 122.0     2
# 126.0     2
# 133.0     2
# 129.0     2
# 128.0     2
# 140.0     1
# 120.0     1
# 131.0     1
# 137.0     1
# Name: Wheelbase, dtype: int64

# %%
#covariance of two column
kp[['Cylinders','Horsepower']].cov()
# Out:
#             Cylinders   Horsepower
# Cylinders    2.428743    90.915272
# Horsepower  90.915272  5160.415434

# %%
teju = kp.cov()
teju
# Out:
#              EngineSize   Cylinders    Horsepower     MPG_City  MPG_Highway  \
# EngineSize     1.228982    1.561558     62.708992    -4.119941    -4.565384
# Cylinders      1.561558    2.428743     90.915272    -5.598177    -6.061022
# Horsepower    62.708992   90.915272   5160.415434  -254.637057  -266.919603
# MPG_City      -4.119941   -5.598177   -254.637057    27.438924    28.299930
# MPG_Highway   -4.565384   -6.061022   -266.919603    28.299930    32.961386
# Weight       679.742938  878.933841  34392.465364 -2933.945632 -3446.716934
# Wheelbase      5.865143    7.097586    231.310436   -22.086673   -25.036694
# Length        10.146386   12.264601    393.542729   -37.719944   -38.420927
#
#                     Weight    Wheelbase       Length
# EngineSize      679.742938     5.865143    10.146386
# Cylinders       878.933841     7.097586    12.264601
# Horsepower    34392.465364   231.310436   393.542729
# MPG_City      -2933.945632   -22.086673   -37.719944
# ...

# %%
#heatmap
sns.heatmap(teju,annot=True,vmin=.2,vmax=3)

# %%
#covariance of two column
kp[['Cylinders','Horsepower']].corr()
# Out:
#             Cylinders  Horsepower
# Cylinders    1.000000    0.810341
# Horsepower   0.810341    1.000000

# %%
#Distplot
sns.distplot(kp[['Cylinders','Horsepower']])

# %%
sns.distplot(kp.Cylinders, color = 'red')

# %%
#Histogram
kp.plot.hist(x='Cylinders',y='Horsepower')
plt.show()

# %%
#ScatterPlot
kp.plot.scatter(x='Weight',y='Horsepower')
plt.show()

# %%
#barplot
kp[['Cylinders','Horsepower']].plot.bar()

# %%
#Boxplot
kp.plot.box(x='Horsepower')
plt.show()

# %%
#print 2nd column of third and fourth row 
kp.iloc[2:4, 1:2]
# Out:
#      Model
# 2  TSX 4dr
# 3   TL 4dr

# %%
#skewness
kp.skew()
# Out:
# EngineSize     0.708152
# Cylinders      0.592785
# Horsepower     0.930331
# MPG_City       2.782072
# MPG_Highway    1.252395
# Weight         0.891824
# Wheelbase      0.962287
# Length         0.181977
# dtype: float64

# %%
#kurtosis
kp.kurt()
# Out:
# EngineSize      0.541944
# Cylinders       0.440378
# Horsepower      1.552159
# MPG_City       15.791147
# MPG_Highway     6.045611
# Weight          1.688789
# Wheelbase       2.133649
# Length          0.614725
# dtype: float64

# %%
#standard deviation
kp.std()
# Out:
# EngineSize       1.108595
# Cylinders        1.558443
# Horsepower      71.836032
# MPG_City         5.238218
# MPG_Highway      5.741201
# Weight         758.983215
# Wheelbase        8.311813
# Length          14.357991
# dtype: float64

# %%
#variance
kp.Weight.var()
# Out:
# 576055.520059533

# %%
#Checking for Null Values
kp.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
kp.notnull().sum()
# Out:
# Make           428
# Model          428
# Type           428
# Origin         428
# DriveTrain     428
# MSRP           428
# Invoice        428
# EngineSize     428
# Cylinders      426
# Horsepower     428
# MPG_City       428
# MPG_Highway    428
# Weight         428
# Wheelbase      428
# Length         428
# dtype: int64

# %%
sns.relplot(data = kp, x = "Cylinders", y = "Horsepower", color = 'purple')

# %%
sns.jointplot(data = kp, x = "Cylinders", y = "Horsepower", color = 'green')

# %%
sns.pairplot(kp)

# %%
plt.figure(figsize = (14 , 5))
sns.barplot(x = 'Cylinders', y = 'Horsepower', data = kp)
plt.xticks(rotation = -45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %% [markdown]
# # Some Question Occurs:-

# %% [markdown]
# # Q1: Find all null value in the dataset.if there is any null value in any column,then fit it with the mean of that column?

# %%
kp.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %% [markdown]
# # Q2:Check what are the different types of make are there in our dataset,and what is the count(occurence)of each make in the data?

# %%
kp['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Mazda            11
# Subaru           11
# Pontiac          11
# Kia              11
# Lexus            11
# Lincoln           9
# Mercury           9
# Buick             9
# Infiniti          8
# Suzuki            8
# Cadillac          8
# Saturn            8
# GMC               8
# Porsche           7
# Acura             7
# Saab              7
# Jeep              3
# Land Rover        3
# Oldsmobile        3
# MINI              2
# Isuzu             2
# Scion             2
# Hummer            1
# Name: Make, dtype: int64

# %%
kp['Make'].describe()
# Out:
# count        428
# unique        38
# top       Toyota
# freq          28
# Name: Make, dtype: object

# %% [markdown]
# # Q3: Show all the records where origin is Asia or Europe?

# %%
kp[kp['Origin'].isin(['Asia','Europe'])]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# # Q4:Remove all the records(rows) where weight is above 4000?

# %%
kp[~(kp['Weight']>4000)]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# # Q5:Increase all the values of 'MPG_City' column by 3?

# %%
kp['MPG_City']=kp['MPG_City'].apply(lambda x:x+3)
kp.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      38.0         23.0  4451.0
# 1         2.0        4.0       200.0      45.0         31.0  2778.0
# 2         2.4        4.0       200.0      43.0         29.0  3230.0
# 3         3.2        6.0       270.0      41.0         28.0  3575.0
# 4         3.5        6.0       225.0      39.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
kp.duplicated().sum()
# Out:
# 3

# %%
kp.drop_duplicates()
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
sns.countplot(x=kp['Horsepower'])

# %%
cols = ['Red', 'Blue']
kp['Horsepower'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True, colors=cols)

# %%
plt.figure(figsize=(16,8))
plt.bar('Cylinders','Horsepower', data=kp)
plt.show()

# %%
sns.countplot(x=kp['Cylinders'])

# %%
plt.figure(figsize = (10,4))
sns.lineplot('Cylinders','Horsepower', data = kp, color = 'r', label= 'Cylinders')
plt.legend()

# %%
kp.hist(bins=50 ,figsize=(20,15))
plt.show()

# %%
fig, axes = plt.subplots(figsize = (10 , 10))

sns.boxplot(kp['Cylinders'])

# %%
Q1 = kp.quantile(q = 0.25, axis = 0, numeric_only = True, interpolation = 'linear')

Q3 = kp.quantile(q = 0.75, axis = 0, numeric_only = True, interpolation = 'linear')

# %%
IQR = Q3 - Q1

print(IQR)
# Out:
# EngineSize       1.525
# Cylinders        2.000
# Horsepower      90.000
# MPG_City         4.250
# MPG_Highway      5.000
# Weight         873.750
# Wheelbase        9.000
# Length          16.000
# dtype: float64

# %%
kp.boxplot()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # THANK YOU
